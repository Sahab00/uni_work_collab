# %%
#using API to extract features (Open, High, Low, Close, Volume)

# %%
# !pip install ccxt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.6/288.6 kB 20.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.13
#     Uninstalling aiohttp-3.11.13:
#       Successfully uninstalled aiohttp-3.11.13
# ...

# %%
import ccxt

# Initialize exchange
exchange = ccxt.binanceus()  # Binance.US ka use karein
symbol = 'BTC/USDT'  # Crypto pair
timeframe = '1h'  # 1-hour interval

# Fetch OHLCV data
ohlcv = exchange.fetch_ohlcv(symbol, timeframe)

# Feature Names
feature_names = ["Timestamp", "Open", "High", "Low", "Close", "Volume"]

# Print Features Row-wise
print(feature_names)  # Print feature names
for row in ohlcv[:100]:  # Print data rows
    print(row)
# Out:
# ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
# [1739916000000, 95011.92, 95447.63, 94896.01, 95237.31, 0.74031]
# [1739919600000, 95345.67, 95602.81, 95332.98, 95602.81, 0.14829]
# [1739923200000, 95602.8, 95763.23, 95321.57, 95321.57, 0.10912]
# [1739926800000, 95339.92, 95453.82, 95087.47, 95453.82, 0.12201]
# [1739930400000, 95525.99, 95879.55, 95501.45, 95767.95, 0.9417]
# [1739934000000, 95815.47, 95831.32, 95618.87, 95673.12, 0.03628]
# [1739937600000, 95684.24, 95730.6, 95195.73, 95196.09, 0.12077]
# [1739941200000, 95196.45, 95351.84, 95087.41, 95268.75, 0.05291]
# [1739944800000, 95331.79, 95629.37, 95252.04, 95598.29, 0.08075]
# [1739948400000, 95642.05, 95852.25, 95573.84, 95719.3, 0.11187]
# [1739952000000, 95711.27, 95869.87, 95674.48, 95674.48, 0.0119]
# [1739955600000, 95692.92, 95891.22, 95692.92, 95891.22, 0.02279]
# [1739959200000, 95891.23, 96347.34, 95891.23, 96313.42, 0.14491]
# [1739962800000, 96312.84, 96362.91, 96217.81, 96362.91, 0.23457]
# ...

# %%
#Technical Indicators (RSI, MACD, etc.)

# %%
# !pip install pandas-ta
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=3d52e963b6441cdebca909f20aa61fcd3123ba68d18d25d9f4fe07f5d1dfd4bd
#   Stored in directory: /root/.cache/pip/wheels/7f/33/8b/50b245c5c65433cd8f5cb24ac15d97e5a3db2d41a8b6ae957d
# Successfully built pandas-ta
# ...

# %%
import pandas as pd
import pandas_ta as ta

# Data ko DataFrame mein convert karna
data = [
    [1739912400000, 94201.79, 95258.07, 94201.79, 94903.38, 0.29956],
    [1739916000000, 95011.92, 95447.63, 94896.01, 95237.31, 0.74031],
    [1739919600000, 95345.67, 95602.81, 95332.98, 95602.81, 0.14829],
    [1739923200000, 95602.8, 95763.23, 95321.57, 95321.57, 0.10912],
    [1739926800000, 95339.92, 95453.82, 95087.47, 95453.82, 0.12201],
    [1739930400000, 95525.99, 95879.55, 95501.45, 95767.95, 0.9417],
    [1740063600000, 96968.05, 97332.81, 96855.53, 96917.98, 0.11985],
    [1740067200000, 96899.64, 97911.71, 96899.63, 97514.97, 0.18616],
    [1740070800000, 97520.46, 97999.99, 97520.46, 97999.98, 0.61431],
    [1740074400000, 97959.49, 98425.31, 97959.49, 98308.43, 1.95691],
    [1740078000000, 98299.93, 98462.94, 98262.48, 98447.65, 0.14655],
    [1740081600000, 98399.99, 98650.58, 98293.58, 98319.59, 2.29983],
    [1740085200000, 98456.85, 98469.98, 97980.46, 97980.47, 0.20666],
    [1740088800000, 97980.47, 98355.04, 97980.47, 98189.74, 0.45962]
]

columns = ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
df = pd.DataFrame(data, columns=columns)
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='ms')
df.set_index('Timestamp', inplace=True)

# Technical Indicators calculate karna
df['RSI'] = ta.rsi(df['Close'], length=14)
df[['MACD', 'MACD_Hist', 'MACD_Signal']] = ta.macd(df['Close'], fast=12, slow=26, signal=9)
df['EMA_20'] = ta.ema(df['Close'], length=20)
df[['BB_Lower', 'BB_Middle', 'BB_Upper']] = ta.bbands(df['Close'], length=20)[['BBL_20_2.0', 'BBM_20_2.0', 'BBU_20_2.0']]

df.dropna(inplace=True)  # NaN values ko remove karna
print(df.head())  # Pehle kuch rows print karna
# Out:
#                          Open      High       Low     Close   Volume  \
# Timestamp
# 2025-02-20 06:00:00  97031.42  97031.42  96836.83  96888.95  0.56289
# 2025-02-20 07:00:00  96895.91  97128.23  96836.83  97016.34  0.08680
# 2025-02-20 08:00:00  97013.30  97235.54  96836.83  97160.56  0.09927
# 2025-02-20 09:00:00  97174.76  97296.82  97146.42  97167.09  0.05071
# 2025-02-20 10:00:00  97270.71  97399.29  97112.73  97399.29  0.05714
#
#                            RSI        MACD  MACD_Hist  MACD_Signal  \
# Timestamp
# 2025-02-20 06:00:00  60.574047  395.772622  16.829621   378.943001
# 2025-02-20 07:00:00  62.454583  387.842506   7.119603   380.722902
# 2025-02-20 08:00:00  64.517980  388.714323   6.393136   382.321186
# 2025-02-20 09:00:00  64.612810  385.488489   2.533842   382.954647
# 2025-02-20 10:00:00  67.898282  397.091173  11.309221   385.781952
#
#                            EMA_20      BB_Lower   BB_Middle      BB_Upper
# Timestamp
# ...

# %%
#Order Book Analysis

# %%
''' Order Book Kya Hota Hai?
Order Book ek real-time list hoti hai buy aur sell orders ki jo kisi market mein place ki gayi hoti hain. Ismein "Bids" (Buy Orders) aur "Asks" (Sell Orders) hoti hain.

Bids (Buy Orders) → Buyers jo kisi specific price par Bitcoin kharidna chahte hain
Asks (Sell Orders) → Sellers jo kisi specific price par Bitcoin bechna chahte hain'''

# %%
order_book = exchange.fetch_order_book('BTC/USDT')
print(order_book)
# Out:
# {'symbol': 'BTC/USDT', 'bids': [[80698.12, 0.64709], [80698.11, 0.00425], [80678.36, 0.11278], [80659.53, 0.00182], [80555.82, 0.2001], [80555.81, 0.0423], [80555.56, 4e-05], [80535.85, 0.09891], [80535.84, 0.00041], [80525.17, 0.00033], [80496.03, 2e-05], [80482.78, 0.00037], [80472.25, 0.0001], [80438.6, 0.1722], [80427.1, 0.16575], [80425.6, 0.00096], [80419.2, 0.17189], [80411.68, 7e-05], [80398.79, 0.00033], [80398.31, 0.00113], [80382.64, 0.0005], [80336.63, 2e-05], [80298.33, 0.0024], [80294.93, 0.00041], [80271.47, 0.00119], [80246.98, 0.00039], [80246.33, 0.00015], [80244.2, 0.25236], [80243.91, 0.00158], [80203.3, 0.25462], [80195.41, 0.00113], [80178.47, 0.00183], [80122.82, 0.00033], [80088.79, 0.00028], [80084.75, 0.00037], [80082.2, 0.16842], [80066.95, 0.01772], [80054.74, 0.00041], [80026.65, 0.00096], [80015.32, 2e-05], [80000.0, 0.00503], [79984.22, 0.0005], [79983.49, 0.00425], [79920.27, 0.0004], [79919.55, 0.00142], [79919.27, 0.00033], [79918.8, 0.00113], [79884
# ...

# %%
import ccxt

exchange = ccxt.binanceus()  # Binance .us use
order_book = exchange.fetch_order_book('BTC/USDT')

# Print Buy Orders (Bids)
print("Bids (Buy Orders):")
for bid in order_book['bids']:
    print(f"Price: {bid[0]}, Quantity: {bid[1]}")

# Print Sell Orders (Asks)
print("\nAsks (Sell Orders):")
for ask in order_book['asks']:
    print(f"Price: {ask[0]}, Quantity: {ask[1]}")
# Out:
# Bids (Buy Orders):
# Price: 80901.49, Quantity: 0.8367
# Price: 80901.48, Quantity: 0.14121
# Price: 80881.06, Quantity: 0.07717
# Price: 80829.44, Quantity: 0.0001
# Price: 80780.1, Quantity: 0.17189
# Price: 80777.47, Quantity: 0.00041
# Price: 80739.6, Quantity: 0.1722
# Price: 80699.2, Quantity: 0.16575
# Price: 80698.11, Quantity: 0.00425
# Price: 80659.53, Quantity: 0.00182
# Price: 80555.57, Quantity: 0.25236
# Price: 80555.56, Quantity: 4e-05
# Price: 80535.84, Quantity: 0.00041
# Price: 80525.17, Quantity: 0.00033
# Price: 80496.03, Quantity: 2e-05
# Price: 80482.78, Quantity: 0.00037
# Price: 80457.6, Quantity: 0.25462
# Price: 80425.6, Quantity: 0.00096
# Price: 80411.68, Quantity: 7e-05
# Price: 80398.79, Quantity: 0.00033
# Price: 80398.31, Quantity: 0.00113
# Price: 80382.64, Quantity: 0.0005
# Price: 80336.63, Quantity: 2e-05
# Price: 80298.33, Quantity: 0.0024
# Price: 80294.93, Quantity: 0.00041
# Price: 80271.47, Quantity: 0.00119
# ...

# %%
#News & Sentiment Analysis (NLP)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
text = "Bitcoin price is skyrocketing!"
sentiment = analyzer.polarity_scores(text)

print(sentiment)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
